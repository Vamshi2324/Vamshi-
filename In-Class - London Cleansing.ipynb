# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("https://raw.githubusercontent.com/Vamshi2324/Vamshi-/main/BL-Flickr-Images-Book-truncated50-checkpoint.csv")

# %%
# df.column=['Identifier','Edition Statement','Place of Publication','Date of Publication','Publisher','Title','Author','Contributors','Corporate Author','Corporate Contributors','Former owner','Engraver','Issuance type','Flickr URL','Shelfmarks']

# %%
# df.drop(['Identifier','Edition Statement','Corporate Author','Corporate Contributors','Former owner','Engraver','Issuance type','Flickr URL','Shelfmarks'], axis=1)

# %%
options = ['London', 'LONDON']
  
# selecting rows based on condition
result_df = df[df['Place of Publication'].isin(options)]

# %%
result_df.drop(['Identifier','Edition Statement','Contributors','Corporate Author','Corporate Contributors','Former owner','Engraver','Issuance type','Flickr URL','Shelfmarks'], axis=1)
# result_df.head()
# Out:
#    Place of Publication Date of Publication               Publisher  \
# 0                London         1879 [1878]        S. Tinsley & Co.
# 4                London                1857    Wertheim & Macintosh
# 5                London                1875       William Macintosh
# 6                LONDON                1872              The Author
# 23               London  1847, 48 [1846-48]            Punch Office
# 24               London             [1897?]   Bradbury, Agnew & Co.
# 25               London             [1897?]   Bradbury, Agnew & Co.
# 32               London                1892  Effingham Wilson & Co.
# 33               London                1894        Effingham Wilson
# 36               London                1899        W. Thacker & Co.
# 37               London              [1885]  Griffith, Farran & Co.
# 38               London             [1860?]            Adams & King
# 40               London                1893         T. Fisher Unwin
# ...
