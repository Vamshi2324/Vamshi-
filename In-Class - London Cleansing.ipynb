# %%
import pandas as pd
import numpy as np
import re

# %%
df=pd.read_csv("https://raw.githubusercontent.com/Vamshi2324/Vamshi-/main/BL-Flickr-Images-Book-truncated50.csv")
df.head()

# %%
df1 = df[df['Place of Publication'].str.contains("London" , flags = re.IGNORECASE )]

# %%
df1.drop(['Identifier','Edition Statement','Contributors','Corporate Author','Corporate Contributors','Former owner','Engraver','Issuance type','Flickr URL','Shelfmarks'], axis=1)
# Out:
#                 Place of Publication Date of Publication  \
# 0                             London         1879 [1878]
# 1           London; Virtue & Yorston                1868
# 4                             London                1857
# 5                             London                1875
# 6                             LONDON                1872
# 8                            London]                167-
# 15                 New York & London                1865
# 21                           London_                1820
# 23                            London  1847, 48 [1846-48]
# 24                            London             [1897?]
# 25                            London             [1897?]
# 27                      NYC_&_London                18O5
# 32                            London                1892
# 33                            London                1894
# 35  pp. 40. W. Cann: London, [1876?]                 NaN
# ...
